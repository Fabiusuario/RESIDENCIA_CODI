# %% [markdown]
# <a href="https://colab.research.google.com/github/Fabiusuario/RESIDENCIA_CODI/blob/master/K_PROTOTYPE_Proyecto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # New Section

# %%
# !pip install flask pyngrok

# %%
# !ngrok config add-authtoken 2nOqUP8lpJT1C1a8fxpmsogoSzF_65oWr1NE2ac8SKwHjJ7E6
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
# !python ./app.py
