# %% [markdown]
# <a href="https://colab.research.google.com/github/Fabiusuario/RESIDENCIA_CODI/blob/master/K_PROTOTYPE_COLAB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # New Section

# %%
# !git clone https://github.com/Fabiusuario/RESIDENCIA_CODI.git
# Out:
# fatal: destination path 'RESIDENCIA_CODI' already exists and is not an empty directory.

# %%
# %cd ./RESIDENCIA_CODI
# !pip install flask pyngrok
ngrok config add-authtoken 2nPozSEortcYVtynSyMPNmVgTLi_31CAY2z1S3rob4KQfqHZ3
# !python ./app.py
# Out:
# [Errno 2] No such file or directory: './RESIDENCIA_CODI'
# /content/RESIDENCIA_CODI
# ...
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml
# ngrok tunnel URL: NgrokTunnel: "https://40d4-34-23-128-146.ngrok-free.app" -> "http://localhost:5000"
#  * Serving Flask app 'app'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [14/Oct/2024 05:22:08] "GET / HTTP/1.1" 404 -
# 127.0.0.1 - - [14/Oct/2024 05:22:08] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [14/Oct/2024 05:22:11] "GET /init HTTP/1.1" 200 -
